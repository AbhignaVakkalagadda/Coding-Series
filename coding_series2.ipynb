# %% [markdown]
# **22-07-2025**

# %% [markdown]
# **Linked List**
#
# It is a non contagious data structure memory allocate
#
# memory allocate
#
# access
#
# 2 4 6 8 7 5 3
#
# 1.single Linked List
#
# 2.Double Linked List
#
# 3.Circular Linked List

# %% [markdown]
# **Single Linked List**

# %% [markdown]
# Head-->node1-->node2-->tail/null
#
# example
#
# class node:
#
#      def __init__(self,data):
#                 self.data=data
#                 self.next=None

# %% [markdown]
# **Insertion**
#
# 1.At begin
#
# 2.At End
#
# 3.At specific Location

# %% [markdown]
# **At Begin**

# %%
class node:
  def __init__(self,data):
    self.data=data
    self.next=None
class LinkedList:
  def __init__(self):
    self.head=None
  def iab(self,data):
    newnode=node(data)
    newnode.next=self.head
    self.head=newnode
    print(f"{data} inserted from begin.. ")
  def display(self):
    current=self.head
    if not current:
      print("LL - Empty")
      return
    while current:
      print(current.data,end="--- ")
      current=current.next
    print("None")
ll=LinkedList()
while True:
  print("\n LinkedList - Insert at begining....")
  print("1.Insert")
  print("2.display")
  print("3.Exit")
  choice=int(input("Enter your choice:"))
  if choice==1:
    data=int(input("Enter the data:"))
    ll.iab(data)
  elif choice==2:
    ll.display()
  elif choice==3:
    print("Exited the operation.....")
    break
  else:
    print("Invalid choice")
# Out:
#  LinkedList - Insert at begining....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:1
# Enter the data:44
# 44 inserted from begin..
#
#  LinkedList - Insert at begining....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:2
# 44--- None
#
#  LinkedList - Insert at begining....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:1
# Enter the data:56
# 56 inserted from begin..
#
#  LinkedList - Insert at begining....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:1
# Enter the data:50
# 50 inserted from begin..
#
#  LinkedList - Insert at begining....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:2
# 50--- 56--- 44--- None
#
#  LinkedList - Insert at begining....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:3
# Exited the operation.....

# %% [markdown]
# **Insert at end**

# %%
class node:
  def __init__(self,data):
    self.data=data
    self.next=None
class LinkedList:
  def __init__(self):
    self.head=None
  def iae(self,data):
    newnode=node(data)
    if not self.head:
      self.head = newnode
      print(f"{data} inserted at end.. ")
      return
    current = self.head
    while current.next:
      current = current.next
    current.next = newnode
    print(f"{data} inserted at end.. ")

  def display(self):
    current=self.head
    if not current:
      print("LL - Empty")
      return
    while current:
      print(current.data,end="--- ")
      current=current.next
    print("None")
ll=LinkedList()
while True:
  print("\n LinkedList - Insert at end....")
  print("1.Insert")
  print("2.display")
  print("3.Exit")
  choice=int(input("Enter your choice:"))
  if choice==1:
    data=int(input("Enter the data:"))
    ll.iae(data)
  elif choice==2:
    ll.display()
  elif choice==3:
    print("Exited the operation.....")
    break
  else:
    print("Invalid choice")
# Out:
#  LinkedList - Insert at end....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:1
# Enter the data:56
# 56 inserted at end..
#
#  LinkedList - Insert at end....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:1
# Enter the data:44
# 44 inserted at end..
#
#  LinkedList - Insert at end....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:1
# Enter the data:32
# 32 inserted at end..
#
#  LinkedList - Insert at end....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:1
# Enter the data:4
# 4 inserted at end..
#
#  LinkedList - Insert at end....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:2
# 56--- 44--- 32--- 4--- None
#
#  LinkedList - Insert at end....
# 1.Insert
# 2.display
# 3.Exit
# Enter your choice:3
# Exited the operation.....

# %% [markdown]
# **Insert at specific location**

# %%
class node:
  def __init__(self,data):
    self.data=data
    self.next=None

class LinkedList:
  def __init__(self):
    self.head=None

  def iasl(self, data, position):
    newnode = node(data)
    if position == 0:
      print("\n--- Inserting at the beginning (position 0) ---")
      newnode.next = self.head
      self.head = newnode
      print(f"{data} inserted at position {position}..")
      return
    if position < 0:
      print("Position cannot be negative")
      return
    current = self.head
    count = 0
    while current and count < position - 1:
      current = current.next
      count += 1
    if not current:
      print("Position out of bounds")
      return

    if current.next is None:
        print("\n--- Inserting at the end ---")
    else:
        print("\n--- Inserting in the middle ---")

    newnode.next = current.next
    current.next = newnode
    print(f"{data} inserted at position {position}..")


  def display(self):
    current=self.head
    if not current:
      print("LL - Empty")
      return
    while current:
      print(current.data,end="--- ")
      current=current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at specific location....")
  print("1.Insert at specific location")
  print("2.display")
  print("3.Exit")
  choice=int(input("Enter your choice:"))
  if choice==1:
    data=int(input("Enter the data:"))
    position = int(input("Enter the position to insert:"))
    ll.iasl(data, position)
  elif choice==2:
    ll.display()
  elif choice==3:
    print("Exited the operation.....")
    break
  else:
    print("Invalid choice")
# Out:
#  LinkedList - Insert at specific location....
# 1.Insert at specific location
# 2.display
# 3.Exit
# Enter your choice:1
# Enter the data:10
# Enter the position to insert:0
#
# --- Inserting at the beginning (position 0) ---
# 10 inserted at position 0..
#
#  LinkedList - Insert at specific location....
# 1.Insert at specific location
# 2.display
# 3.Exit
# Enter your choice:1
# Enter the data:30
# Enter the position to insert:2
# Position out of bounds
#
#  LinkedList - Insert at specific location....
# 1.Insert at specific location
# 2.display
# 3.Exit
# Enter your choice:1
# Enter the data:20
# Enter the position to insert:1
#
# --- Inserting at the end ---
# 20 inserted at position 1..
#
#  LinkedList - Insert at specific location....
# 1.Insert at specific location
# 2.display
# 3.Exit
# Enter your choice:2
# 10--- 20--- None
#
#  LinkedList - Insert at specific location....
# 1.Insert at specific location
# 2.display
# 3.Exit
# Enter your choice:3
# Exited the operation.....

# %% [markdown]
# Search operation where element in the node is present or not

# %%
class node:
  def __init__(self,data):
    self.data=data
    self.next=None

class LinkedList:
  def __init__(self):
    self.head=None

  def iae(self, data):
    newnode = node(data)
    if not self.head:
      self.head = newnode
      return
    current = self.head
    while current.next:
      current = current.next
    current.next = newnode
  def search(self,key):
    pos=1
    current=self.head
    while current:
      if current.data==key:
        print(f"{key} found at position {pos}")
        return True
      current=current.next
      pos+=1
    print(f"{key} not found in LL")
    return False
  def display(self):
    current=self.head
    if not current:
      print("LL - Empty")
      return
    while current:
      print(current.data,end="--- ")
      current=current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Operations....") # More general message
  print("1.Insert ") # Changed option text
  print("2.display")
  print("3.Search")
  print("4.Exit")
  choice=int(input("Enter your choice:"))
  if choice==1:
    data=int(input("Enter the data:"))
    ll.iae(data) # Removed the position argument
  elif choice==2:
    ll.display()
  elif choice==3:
    val=int(input("Enter the value to search:"))
    ll.search(val)
  elif choice==4:
    print("Exited the operation.....")
    break
  else:
    print("Invalid choice")
# Out:
#  LinkedList - Operations....
# 1.Insert
# 2.display
# 3.Search
# 4.Exit
# Enter your choice:1
# Enter the data:23
#
#  LinkedList - Operations....
# 1.Insert
# 2.display
# 3.Search
# 4.Exit
# Enter your choice:1
# Enter the data:23
#
#  LinkedList - Operations....
# 1.Insert
# 2.display
# 3.Search
# 4.Exit
# Enter your choice:1
# Enter the data:43
#
#  LinkedList - Operations....
# 1.Insert
# 2.display
# 3.Search
# 4.Exit
# Enter your choice:2
# 23--- 23--- 43--- None
#
#  LinkedList - Operations....
# 1.Insert
# 2.display
# 3.Search
# 4.Exit
# Enter your choice:3
# Enter the value to search:23
# 23 found at position 1
#
#  LinkedList - Operations....
# 1.Insert
# 2.display
# 3.Search
# 4.Exit
# Enter your choice:4
# Exited the operation.....
